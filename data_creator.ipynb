# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
instances = 20
k_repetitions = 10
k_range = np.linspace(0, k_repetitions - 1, num=k_repetitions)

regularizations = ['L2', 'dropout']
l2_no = 50
l2_range = (0.001, 0.1)
drop_no = 50
drop_range = (0.1, 0.5)

l2_values = np.linspace(l2_range[0], l2_range[1], l2_no)
drop_values = np.linspace(drop_range[0], drop_range[1], drop_no)

print(l2_values)
print(drop_values)

# Define parameters for Gaussian noise
mean = 0  # Mean of the Gaussian distribution
std_dev = 0.1  # Standard deviation of the Gaussian distribution
# Out:
# [0.001      0.00302041 0.00504082 0.00706122 0.00908163 0.01110204
#  0.01312245 0.01514286 0.01716327 0.01918367 0.02120408 0.02322449
#  0.0252449  0.02726531 0.02928571 0.03130612 0.03332653 0.03534694
#  0.03736735 0.03938776 0.04140816 0.04342857 0.04544898 0.04746939
#  0.0494898  0.0515102  0.05353061 0.05555102 0.05757143 0.05959184
#  0.06161224 0.06363265 0.06565306 0.06767347 0.06969388 0.07171429
#  0.07373469 0.0757551  0.07777551 0.07979592 0.08181633 0.08383673
#  0.08585714 0.08787755 0.08989796 0.09191837 0.09393878 0.09595918
#  0.09797959 0.1       ]
# [0.1        0.10816327 0.11632653 0.1244898  0.13265306 0.14081633
#  0.14897959 0.15714286 0.16530612 0.17346939 0.18163265 0.18979592
#  0.19795918 0.20612245 0.21428571 0.22244898 0.23061224 0.23877551
#  0.24693878 0.25510204 0.26326531 0.27142857 0.27959184 0.2877551
#  0.29591837 0.30408163 0.3122449  0.32040816 0.32857143 0.33673469
#  0.34489796 0.35306122 0.36122449 0.36938776 0.37755102 0.38571429
#  0.39387755 0.40204082 0.41020408 0.41836735 0.42653061 0.43469388
#  0.44285714 0.45102041 0.45918367 0.46734694 0.4755102  0.48367347
#  0.49183673 0.5       ]

# %%
def calculate_x(x_value):
    return 0.1 * np.exp(-1 * x_value)

def calculate_y(y_value):
    return 0.1 * y_value ** 2

def create_sequence(sequence_list, df):
    df_length = df.shape[0]
    # repeated_sequence = sequence_list * (df_length // len(sequence_list)) + sequence_list[:df_length % len(sequence_list)]
    repeated_sequence =  [sequence_list[i % len(sequence_list)] for i in range(df_length)]
    return repeated_sequence

def sequence(sequence_list, df):
    df_length = df.shape[0]
    # sequence = sequence_list[0] * (df_length // 2) + sequence_list[1] * (df_length // 2)
    first_half_repeats = df_length // 2
    second_half_repeats = df_length - first_half_repeats

    # Create a column with alternating items from the sequence list
    sequence = [sequence_list[0]] * first_half_repeats + [sequence_list[1]] * second_half_repeats
    return sequence

# %%
df = pd.DataFrame()#columns = ['added_instances'])#, 'repetition', 'reg_type', 'reg_value'])

# %%
df['id'] = range(instances * len(regularizations) * (l2_no + drop_no) * k_repetitions)
print(df.shape)
# Out:
# (40000, 1)

# %%
# instances_list = np.linspace(0, instances-1, instances)
# print(instances_list)
# instance_reps = len(regularizations) * (l2_no + drop_no) * k_repetitions
# print(instance_reps)
# # instance_reps

# %%
# df['instance_no'].unique()

# %%
instances_list = np.linspace(0, instances-1, instances)
instance_reps = len(regularizations) * (l2_no + drop_no) * k_repetitions

instance_sequence = create_sequence([x for x in instances_list for _ in range(len(instances_list))], df)
df['instance_no'] = instance_sequence
print(df.shape)
print(df.head(60))
print(df.tail(60))
# print(df.iloc[80:120,:])
# Out:
# (40000, 2)
#     id  instance_no
# 0    0          0.0
# 1    1          0.0
# 2    2          0.0
# 3    3          0.0
# 4    4          0.0
# 5    5          0.0
# 6    6          0.0
# 7    7          0.0
# 8    8          0.0
# 9    9          0.0
# 10  10          0.0
# 11  11          0.0
# 12  12          0.0
# 13  13          0.0
# 14  14          0.0
# 15  15          0.0
# 16  16          0.0
# 17  17          0.0
# 18  18          0.0
# 19  19          0.0
# 20  20          1.0
# 21  21          1.0
# 22  22          1.0
# 23  23          1.0
# 24  24          1.0
# 25  25          1.0
# 26  26          1.0
# 27  27          1.0
# 28  28          1.0
# 29  29          1.0
# 30  30          1.0
# 31  31          1.0
# 32  32          1.0
# 33  33          1.0
# 34  34          1.0
# 35  35          1.0
# 36  36          1.0
# 37  37          1.0
# 38  38          1.0
# 39  39          1.0
# 40  40          2.0
# 41  41          2.0
# 42  42          2.0
# 43  43          2.0
# 44  44          2.0
# 45  45          2.0
# 46  46          2.0
# 47  47          2.0
# 48  48          2.0
# 49  49          2.0
# 50  50          2.0
# 51  51          2.0
# 52  52          2.0
# 53  53          2.0
# 54  54          2.0
# 55  55          2.0
# 56  56          2.0
# 57  57          2.0
# 58  58          2.0
# 59  59          2.0
#           id  instance_no
# 39940  39940         17.0
# 39941  39941         17.0
# 39942  39942         17.0
# 39943  39943         17.0
# 39944  39944         17.0
# 39945  39945         17.0
# 39946  39946         17.0
# 39947  39947         17.0
# 39948  39948         17.0
# 39949  39949         17.0
# 39950  39950         17.0
# 39951  39951         17.0
# 39952  39952         17.0
# 39953  39953         17.0
# 39954  39954         17.0
# 39955  39955         17.0
# 39956  39956         17.0
# 39957  39957         17.0
# 39958  39958         17.0
# 39959  39959         17.0
# 39960  39960         18.0
# 39961  39961         18.0
# 39962  39962         18.0
# 39963  39963         18.0
# 39964  39964         18.0
# 39965  39965         18.0
# 39966  39966         18.0
# 39967  39967         18.0
# 39968  39968         18.0
# 39969  39969         18.0
# 39970  39970         18.0
# 39971  39971         18.0
# 39972  39972         18.0
# 39973  39973         18.0
# 39974  39974         18.0
# 39975  39975         18.0
# 39976  39976         18.0
# 39977  39977         18.0
# 39978  39978         18.0
# 39979  39979         18.0
# 39980  39980         19.0
# 39981  39981         19.0
# 39982  39982         19.0
# 39983  39983         19.0
# 39984  39984         19.0
# 39985  39985         19.0
# 39986  39986         19.0
# 39987  39987         19.0
# 39988  39988         19.0
# 39989  39989         19.0
# 39990  39990         19.0
# 39991  39991         19.0
# 39992  39992         19.0
# 39993  39993         19.0
# 39994  39994         19.0
# 39995  39995         19.0
# 39996  39996         19.0
# 39997  39997         19.0
# 39998  39998         19.0
# 39999  39999         19.0

# %%
reg_sequence = sequence(regularizations, df)
df['reg_type'] = reg_sequence
print(df.shape)
print(df.head(20))
print(df.tail(20))
# Out:
# (40000, 3)
#     id  instance_no reg_type
# 0    0          0.0       L2
# 1    1          0.0       L2
# 2    2          0.0       L2
# 3    3          0.0       L2
# 4    4          0.0       L2
# 5    5          0.0       L2
# 6    6          0.0       L2
# 7    7          0.0       L2
# 8    8          0.0       L2
# 9    9          0.0       L2
# 10  10          0.0       L2
# 11  11          0.0       L2
# 12  12          0.0       L2
# 13  13          0.0       L2
# 14  14          0.0       L2
# 15  15          0.0       L2
# 16  16          0.0       L2
# 17  17          0.0       L2
# 18  18          0.0       L2
# 19  19          0.0       L2
#           id  instance_no reg_type
# 39980  39980         19.0  dropout
# 39981  39981         19.0  dropout
# 39982  39982         19.0  dropout
# 39983  39983         19.0  dropout
# 39984  39984         19.0  dropout
# 39985  39985         19.0  dropout
# 39986  39986         19.0  dropout
# 39987  39987         19.0  dropout
# 39988  39988         19.0  dropout
# 39989  39989         19.0  dropout
# 39990  39990         19.0  dropout
# 39991  39991         19.0  dropout
# 39992  39992         19.0  dropout
# 39993  39993         19.0  dropout
# 39994  39994         19.0  dropout
# 39995  39995         19.0  dropout
# 39996  39996         19.0  dropout
# 39997  39997         19.0  dropout
# 39998  39998         19.0  dropout
# 39999  39999         19.0  dropout

# %%
k_sequence = create_sequence(k_range, df)
# len(k_sequence)
df['k_repetition'] = k_sequence
print(df.shape)
print(df.head(20))
print(df.tail(20))
# Out:
# (40000, 4)
#     id  instance_no reg_type  k_repetition
# 0    0          0.0       L2           0.0
# 1    1          0.0       L2           1.0
# 2    2          0.0       L2           2.0
# 3    3          0.0       L2           3.0
# 4    4          0.0       L2           4.0
# 5    5          0.0       L2           5.0
# 6    6          0.0       L2           6.0
# 7    7          0.0       L2           7.0
# 8    8          0.0       L2           8.0
# 9    9          0.0       L2           9.0
# 10  10          0.0       L2           0.0
# 11  11          0.0       L2           1.0
# 12  12          0.0       L2           2.0
# 13  13          0.0       L2           3.0
# 14  14          0.0       L2           4.0
# 15  15          0.0       L2           5.0
# 16  16          0.0       L2           6.0
# 17  17          0.0       L2           7.0
# 18  18          0.0       L2           8.0
# 19  19          0.0       L2           9.0
#           id  instance_no reg_type  k_repetition
# 39980  39980         19.0  dropout           0.0
# 39981  39981         19.0  dropout           1.0
# 39982  39982         19.0  dropout           2.0
# 39983  39983         19.0  dropout           3.0
# 39984  39984         19.0  dropout           4.0
# 39985  39985         19.0  dropout           5.0
# 39986  39986         19.0  dropout           6.0
# 39987  39987         19.0  dropout           7.0
# 39988  39988         19.0  dropout           8.0
# 39989  39989         19.0  dropout           9.0
# 39990  39990         19.0  dropout           0.0
# 39991  39991         19.0  dropout           1.0
# 39992  39992         19.0  dropout           2.0
# 39993  39993         19.0  dropout           3.0
# 39994  39994         19.0  dropout           4.0
# 39995  39995         19.0  dropout           5.0
# 39996  39996         19.0  dropout           6.0
# 39997  39997         19.0  dropout           7.0
# 39998  39998         19.0  dropout           8.0
# 39999  39999         19.0  dropout           9.0

# %%
# # list(l2_values) * k_repetitions
# new_list = [x for x in l2_values for _ in range(k_repetitions)]
# new_list

# %%
# len(l2_sequence)

# %%
l2_sequence = create_sequence([x for x in l2_values for _ in range(k_repetitions)], df) 
drop_sequence = create_sequence([x for x in drop_values for _ in range(k_repetitions)], df)

sequences = {regularizations[0]: l2_sequence, regularizations[1]: drop_sequence}

df['reg_value'] =  [sequences[row['reg_type']][i % len(sequences[row['reg_type']])] for i, row in df.iterrows()]
print(df.shape)
print(df.head(40))
print(df.tail(40))
# Out:
# (40000, 5)
#     id  instance_no reg_type  k_repetition  reg_value
# 0    0          0.0       L2           0.0   0.001000
# 1    1          0.0       L2           1.0   0.001000
# 2    2          0.0       L2           2.0   0.001000
# 3    3          0.0       L2           3.0   0.001000
# 4    4          0.0       L2           4.0   0.001000
# 5    5          0.0       L2           5.0   0.001000
# 6    6          0.0       L2           6.0   0.001000
# 7    7          0.0       L2           7.0   0.001000
# 8    8          0.0       L2           8.0   0.001000
# 9    9          0.0       L2           9.0   0.001000
# 10  10          0.0       L2           0.0   0.003020
# 11  11          0.0       L2           1.0   0.003020
# 12  12          0.0       L2           2.0   0.003020
# 13  13          0.0       L2           3.0   0.003020
# 14  14          0.0       L2           4.0   0.003020
# 15  15          0.0       L2           5.0   0.003020
# 16  16          0.0       L2           6.0   0.003020
# 17  17          0.0       L2           7.0   0.003020
# 18  18          0.0       L2           8.0   0.003020
# 19  19          0.0       L2           9.0   0.003020
# 20  20          1.0       L2           0.0   0.005041
# 21  21          1.0       L2           1.0   0.005041
# 22  22          1.0       L2           2.0   0.005041
# 23  23          1.0       L2           3.0   0.005041
# 24  24          1.0       L2           4.0   0.005041
# 25  25          1.0       L2           5.0   0.005041
# 26  26          1.0       L2           6.0   0.005041
# 27  27          1.0       L2           7.0   0.005041
# 28  28          1.0       L2           8.0   0.005041
# 29  29          1.0       L2           9.0   0.005041
# 30  30          1.0       L2           0.0   0.007061
# 31  31          1.0       L2           1.0   0.007061
# 32  32          1.0       L2           2.0   0.007061
# 33  33          1.0       L2           3.0   0.007061
# 34  34          1.0       L2           4.0   0.007061
# 35  35          1.0       L2           5.0   0.007061
# 36  36          1.0       L2           6.0   0.007061
# 37  37          1.0       L2           7.0   0.007061
# 38  38          1.0       L2           8.0   0.007061
# 39  39          1.0       L2           9.0   0.007061
#           id  instance_no reg_type  k_repetition  reg_value
# 39960  39960         18.0  dropout           0.0   0.475510
# 39961  39961         18.0  dropout           1.0   0.475510
# 39962  39962         18.0  dropout           2.0   0.475510
# 39963  39963         18.0  dropout           3.0   0.475510
# 39964  39964         18.0  dropout           4.0   0.475510
# 39965  39965         18.0  dropout           5.0   0.475510
# 39966  39966         18.0  dropout           6.0   0.475510
# 39967  39967         18.0  dropout           7.0   0.475510
# 39968  39968         18.0  dropout           8.0   0.475510
# 39969  39969         18.0  dropout           9.0   0.475510
# 39970  39970         18.0  dropout           0.0   0.483673
# 39971  39971         18.0  dropout           1.0   0.483673
# 39972  39972         18.0  dropout           2.0   0.483673
# 39973  39973         18.0  dropout           3.0   0.483673
# 39974  39974         18.0  dropout           4.0   0.483673
# 39975  39975         18.0  dropout           5.0   0.483673
# 39976  39976         18.0  dropout           6.0   0.483673
# 39977  39977         18.0  dropout           7.0   0.483673
# 39978  39978         18.0  dropout           8.0   0.483673
# 39979  39979         18.0  dropout           9.0   0.483673
# 39980  39980         19.0  dropout           0.0   0.491837
# 39981  39981         19.0  dropout           1.0   0.491837
# 39982  39982         19.0  dropout           2.0   0.491837
# 39983  39983         19.0  dropout           3.0   0.491837
# 39984  39984         19.0  dropout           4.0   0.491837
# 39985  39985         19.0  dropout           5.0   0.491837
# 39986  39986         19.0  dropout           6.0   0.491837
# 39987  39987         19.0  dropout           7.0   0.491837
# 39988  39988         19.0  dropout           8.0   0.491837
# 39989  39989         19.0  dropout           9.0   0.491837
# 39990  39990         19.0  dropout           0.0   0.500000
# 39991  39991         19.0  dropout           1.0   0.500000
# 39992  39992         19.0  dropout           2.0   0.500000
# 39993  39993         19.0  dropout           3.0   0.500000
# 39994  39994         19.0  dropout           4.0   0.500000
# 39995  39995         19.0  dropout           5.0   0.500000
# 39996  39996         19.0  dropout           6.0   0.500000
# 39997  39997         19.0  dropout           7.0   0.500000
# 39998  39998         19.0  dropout           8.0   0.500000
# 39999  39999         19.0  dropout           9.0   0.500000

# %%
df['loss'] = (np.exp(-1 * df['instance_no'])) + (df['reg_value'] ** 2)
# df['loss'] = calculate_x(df['instance_no']) + calculate_y(df['reg_value'])
df['loss'] = df['loss'] + np.random.normal(mean, std_dev, len(df))
df.head(20)
# Out:
#     id  instance_no reg_type  k_repetition  reg_value      loss
# 0    0          0.0       L2           0.0    0.00100  0.960612
# 1    1          0.0       L2           1.0    0.00100  0.801498
# 2    2          0.0       L2           2.0    0.00100  1.074984
# 3    3          0.0       L2           3.0    0.00100  0.919001
# 4    4          0.0       L2           4.0    0.00100  0.957142
# 5    5          0.0       L2           5.0    0.00100  0.909571
# 6    6          0.0       L2           6.0    0.00100  0.996477
# 7    7          0.0       L2           7.0    0.00100  0.966306
# 8    8          0.0       L2           8.0    0.00100  1.031313
# 9    9          0.0       L2           9.0    0.00100  0.954000
# 10  10          0.0       L2           0.0    0.00302  1.229676
# 11  11          0.0       L2           1.0    0.00302  0.804957
# 12  12          0.0       L2           2.0    0.00302  0.939311
# 13  13          0.0       L2           3.0    0.00302  0.950422
# 14  14          0.0       L2           4.0    0.00302  0.873726
# 15  15          0.0       L2           5.0    0.00302  1.099069
# 16  16          0.0       L2           6.0    0.00302  0.913929
# 17  17          0.0       L2           7.0    0.00302  0.916778
# 18  18          0.0       L2           8.0    0.00302  0.901918
# 19  19          0.0       L2           9.0    0.00302  0.918458

# %%
# print(df.shape)
# df.head(50)

# %%
# df.tail(50)

# %%
df.to_csv('ToyData2.csv', index=False)
